# %%
#-----------------------------------
# csc531 Week2b -- Part1 --Try to read data using url 
# Ref: https://machinelearningmastery.com/load-machine-learning-data-python/
# ---------------------------------
import pandas
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = pandas.read_csv(url, names=names)
print("Diabetes dataset --> Data dimension:")
print(data.shape)
print("Show first 20 data rows:")
print(data.head(20))

#-----------------------------------
# -- Part2 --Try to print out some descriptive statistics of this dataset
#   Ref: https://realpython.com/python-statistics/
#
#   Task1 --> Try to print out other statistics of 'mass', and 'preg' column
#            Such as ... median of 'mass' and 'age' and mode of ,preg,
#   Task2 --> Can you print out Q1 and Q3 of 'mass' ?
#      
# ---------------------------------           
import statistics
print("Mean of mass column:")
print(statistics.mean(data.mass))
print("Median of mass column:")

print("Mode of preg column:")
# Out:
# Diabetes dataset --> Data dimension:
# (768, 9)
# Show first 20 data rows:
#     preg  plas  pres  skin  test  mass   pedi  age  class
# 0      6   148    72    35     0  33.6  0.627   50      1
# 1      1    85    66    29     0  26.6  0.351   31      0
# 2      8   183    64     0     0  23.3  0.672   32      1
# 3      1    89    66    23    94  28.1  0.167   21      0
# 4      0   137    40    35   168  43.1  2.288   33      1
# 5      5   116    74     0     0  25.6  0.201   30      0
# 6      3    78    50    32    88  31.0  0.248   26      1
# 7     10   115     0     0     0  35.3  0.134   29      0
# 8      2   197    70    45   543  30.5  0.158   53      1
# 9      8   125    96     0     0   0.0  0.232   54      1
# 10     4   110    92     0     0  37.6  0.191   30      0
# 11    10   168    74     0     0  38.0  0.537   34      1
# 12    10   139    80     0     0  27.1  1.441   57      0
# 13     1   189    60    23   846  30.1  0.398   59      1
# ...
