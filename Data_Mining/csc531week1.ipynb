# %%
# This is my first Python Sci-kit learn code -- working with Iris dataset
# Week1-Lab:  Ref: https://python-course.eu/machine-learning/data-representation-and-visualization-data.php 
from sklearn.datasets import load_iris
iris = load_iris()
